# %% [markdown]
# # colav automaton simulation testing
#
# This document will show testing of the colav autmoaton running during generated scenarios.

# %%
import xml
import matplotlib.pyplot as plt

scneario_file = '/home/ryan/colav-automaton/notebooks/scenarios/scenario_1.xml'

with open(scneario_file, 'r', encoding='utf-8') as f: 
    xml_file = f.read()


xml_file
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       6 with open(scneario_file, 'r', encoding='utf-8') as f:
#       7     xml_file = f.read()
# ---> 10 plt.subplot(2,2 )
#      11 plt.subplot(2,5)
#
# File ~/.local/lib/python3.12/site-packages/matplotlib/pyplot.py:1551, in subplot(*args, **kwargs)
#    1548 fig = gcf()
#    1550 # First, search for an existing subplot with a matching spec.
# -> 1551 key = SubplotSpec._from_subplot_args(fig, args)
#    1553 for ax in fig.axes:
#    1554     # If we found an Axes at the position, we can reuse it if the user passed no
#    1555     # kwargs or if the Axes class and kwargs are identical.
#    1556     if (ax.get_subplotspec() == key
#    1557         and (kwargs == {}
#    1558              or (ax._projection_init
#    1559                  == fig._process_projection_requirements(**kwargs)))):
#
# ...
