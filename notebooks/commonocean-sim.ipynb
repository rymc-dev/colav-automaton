# %% [markdown]
# # Commonocean Simulator

# %% [markdown]
# for these simulations we use the commonocean configuration with the commonocean python venv, creation details of this evn are in this repo: https://github.com/CommonOcean/commonocean-sim/tree/main
